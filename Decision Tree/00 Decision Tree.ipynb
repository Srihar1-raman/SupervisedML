# %% [markdown]
# <a href='https://srihar1-raman.github.io/srihari.github.io/'><img src='https://srihar1-raman.github.io/srihari.github.io/img/devjane.png'/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../DATA/penguins_size.csv")

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 334 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            334 non-null    object
#  1   island             334 non-null    object
#  2   culmen_length_mm   334 non-null    float64
#  3   culmen_depth_mm    334 non-null    float64
#  4   flipper_length_mm  334 non-null    float64
#  5   body_mass_g        334 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.9+ KB

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        334.000000       334.000000         334.000000   334.000000
# mean          43.994311        17.160479         201.014970  4209.056886
# std            5.460521         1.967909          14.022175   804.836129
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.500000        15.600000         190.000000  3550.000000
# 50%           44.500000        17.300000         197.000000  4050.000000
# 75%           48.575000        18.700000         213.000000  4793.750000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
pd.get_dummies(df, drop_first=True)
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0                39.1             18.7              181.0       3750.0
# 1                39.5             17.4              186.0       3800.0
# 2                40.3             18.0              195.0       3250.0
# 4                36.7             19.3              193.0       3450.0
# 5                39.3             20.6              190.0       3650.0
# ..                ...              ...                ...          ...
# 338              47.2             13.7              214.0       4925.0
# 340              46.8             14.3              215.0       4850.0
# 341              50.4             15.7              222.0       5750.0
# 342              45.2             14.8              212.0       5200.0
# 343              49.9             16.1              213.0       5400.0
#
#      species_Chinstrap  species_Gentoo  island_Dream  island_Torgersen  \
# ...

# %%
pd.get_dummies(df.drop('species',axis=1),drop_first=True)
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0                39.1             18.7              181.0       3750.0
# 1                39.5             17.4              186.0       3800.0
# 2                40.3             18.0              195.0       3250.0
# 4                36.7             19.3              193.0       3450.0
# 5                39.3             20.6              190.0       3650.0
# ..                ...              ...                ...          ...
# 338              47.2             13.7              214.0       4925.0
# 340              46.8             14.3              215.0       4850.0
# 341              50.4             15.7              222.0       5750.0
# 342              45.2             14.8              212.0       5200.0
# 343              49.9             16.1              213.0       5400.0
#
#      island_Dream  island_Torgersen  sex_FEMALE  sex_MALE
# ...

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 4       3450.0  FEMALE
# 5       3650.0    MALE

# %%
X = pd.get_dummies(df.drop('species',axis=1),drop_first=True)
y = df["species"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report, plot_confusion_matrix

# %%
plot_confusion_matrix(model, X_test, y_test)
# Out:
# /Users/user/Downloads/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.98      1.00      0.99        53
#    Chinstrap       1.00      0.95      0.97        20
#       Gentoo       1.00      1.00      1.00        38
#
#     accuracy                           0.99       111
#    macro avg       0.99      0.98      0.99       111
# weighted avg       0.99      0.99      0.99       111

# %%
model.feature_importances_
# Out:
# array([0.34303331, 0.07901097, 0.49750577, 0.00695744, 0.03920224,
#        0.        , 0.02385409, 0.01043617])

# %%
X.columns
# Out:
# Index(['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm',
#        'body_mass_g', 'island_Dream', 'island_Torgersen', 'sex_FEMALE',
#        'sex_MALE'],
#       dtype='object')

# %%
pd.DataFrame(index = X.columns, data = model.feature_importances_, columns = ["Feature Importance"]).sort_values(["Feature Importance"], ascending = False)
# Out:
#                    Feature Importance
# flipper_length_mm            0.497506
# culmen_length_mm             0.343033
# culmen_depth_mm              0.079011
# island_Dream                 0.039202
# sex_FEMALE                   0.023854
# sex_MALE                     0.010436
# body_mass_g                  0.006957
# island_Torgersen             0.000000

# %%
sns.boxplot(x = "species", y = "body_mass_g", data = df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.catplot(x = "species", y = "body_mass_g", data = df, kind = "violin")

# %%
# fig, a = plt.subplots(nrows=2, ncols=2,)
# sns.catplot(x = "species", y = "body_mass_g", data = df, kind = "violin", ax = a[1])
# sns.catplot(x = "species", y = "body_mass_g", data = df, kind = "strip", ax = a[0])
# sns.boxplot(x = "species", y = "body_mass_g", data = df, ax = [1][1])
# sns.boxplot(x = "species", y = "body_mass_g", data = df)
# plt.show()

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(12,8))
plot_tree(model);

# %%
plt.figure(figsize=(12,8),dpi=150)
plot_tree(model,filled=True,feature_names=X.columns);

# %%
def report_model(model):
    pred = model.predict(X_test)
    print(classification_report(y_test, pred))
    plt.figure(figsize = (12, 10), dpi = 200)
    plot_tree(model, filled = True, feature_names=X.columns)

# %%
report_model(model)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.98      1.00      0.99        53
#    Chinstrap       1.00      0.95      0.97        20
#       Gentoo       1.00      1.00      1.00        38
#
#     accuracy                           0.99       111
#    macro avg       0.99      0.98      0.99       111
# weighted avg       0.99      0.99      0.99       111

# %%
help(DecisionTreeClassifier)
# Out:
# Help on class DecisionTreeClassifier in module sklearn.tree._classes:
#
# class DecisionTreeClassifier(sklearn.base.ClassifierMixin, BaseDecisionTree)
#  |  DecisionTreeClassifier(*, criterion='gini', splitter='best', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, min_impurity_decrease=0.0, class_weight=None, ccp_alpha=0.0)
#  |
#  |  A decision tree classifier.
#  |
#  |  Read more in the :ref:`User Guide <tree>`.
#  |
#  |  Parameters
#  |  ----------
#  |  criterion : {"gini", "entropy", "log_loss"}, default="gini"
#  |      The function to measure the quality of a split. Supported criteria are
#  |      "gini" for the Gini impurity and "log_loss" and "entropy" both for the
#  |      Shannon information gain, see :ref:`tree_mathematical_formulation`.
#  |
#  |  splitter : {"best", "random"}, default="best"
#  |      The strategy used to choose the split at each node. Supported
# ...

# %%
pruned_tree = DecisionTreeClassifier(max_depth=2)
pruned_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
report_model(pruned_tree)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.96      1.00      0.98        53
#    Chinstrap       1.00      0.90      0.95        20
#       Gentoo       1.00      1.00      1.00        38
#
#     accuracy                           0.98       111
#    macro avg       0.99      0.97      0.98       111
# weighted avg       0.98      0.98      0.98       111

# %%
pruned_tree = DecisionTreeClassifier(max_depth=1)
pruned_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
report_model(pruned_tree)
# Out:
# /Users/user/Downloads/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/user/Downloads/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/user/Downloads/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
pruned_tree = DecisionTreeClassifier(max_depth=3, max_leaf_nodes=4)
pruned_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, max_leaf_nodes=4)

# %%
report_model(pruned_tree)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.96      1.00      0.98        53
#    Chinstrap       1.00      0.90      0.95        20
#       Gentoo       1.00      1.00      1.00        38
#
#     accuracy                           0.98       111
#    macro avg       0.99      0.97      0.98       111
# weighted avg       0.98      0.98      0.98       111

# %%
pruned_tree = DecisionTreeClassifier(max_depth=2, max_leaf_nodes=3)
pruned_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, max_leaf_nodes=3)

# %%
report_model(pruned_tree)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.96      1.00      0.98        53
#    Chinstrap       1.00      0.85      0.92        20
#       Gentoo       0.97      1.00      0.99        38
#
#     accuracy                           0.97       111
#    macro avg       0.98      0.95      0.96       111
# weighted avg       0.97      0.97      0.97       111

# %%
pruned_tree = DecisionTreeClassifier(criterion="entropy" )
pruned_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
report_model(pruned_tree)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.98      0.98      0.98        53
#    Chinstrap       0.95      0.95      0.95        20
#       Gentoo       1.00      1.00      1.00        38
#
#     accuracy                           0.98       111
#    macro avg       0.98      0.98      0.98       111
# weighted avg       0.98      0.98      0.98       111

# %%
pruned_tree = DecisionTreeClassifier(criterion="log_loss", max_depth = 4, max_leaf_nodes = 6)
pruned_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='log_loss', max_depth=4, max_leaf_nodes=6)

# %%
report_model(pruned_tree)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.98      0.98      0.98        53
#    Chinstrap       0.95      0.95      0.95        20
#       Gentoo       1.00      1.00      1.00        38
#
#     accuracy                           0.98       111
#    macro avg       0.98      0.98      0.98       111
# weighted avg       0.98      0.98      0.98       111

# %%
*Uploaded Photos & Videos*

1.Sparsh
2.sri
